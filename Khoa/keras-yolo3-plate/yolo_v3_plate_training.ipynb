# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My\ Drive/AI_COLAB/YOLO_V3_PLATE
# !pwd
# Out:
# /content/drive/My Drive/AI_COLAB/YOLO_V3_PLATE
# /content/drive/My Drive/AI_COLAB/YOLO_V3_PLATE

# %%
import random
import argparse
import numpy as np

from voc import parse_voc_annotation
import json

# %%
def IOU(ann, centroids):
    w, h = ann
    similarities = []

    for centroid in centroids:
        c_w, c_h = centroid

        if c_w >= w and c_h >= h:
            similarity = w*h/(c_w*c_h)
        elif c_w >= w and c_h <= h:
            similarity = w*c_h/(w*h + (c_w-w)*c_h)
        elif c_w <= w and c_h >= h:
            similarity = c_w*h/(w*h + c_w*(c_h-h))
        else: #means both w,h are bigger than c_w and c_h respectively
            similarity = (c_w*c_h)/(w*h)
        similarities.append(similarity) # will become (k,) shape

    return np.array(similarities)

def avg_IOU(anns, centroids):
    n,d = anns.shape
    sum = 0.

    for i in range(anns.shape[0]):
        sum+= max(IOU(anns[i], centroids))

    return sum/n

def print_anchors(centroids):
    out_string = ''

    anchors = centroids.copy()

    widths = anchors[:, 0]
    sorted_indices = np.argsort(widths)

    r = "anchors: ["
    for i in sorted_indices:
        out_string += str(int(anchors[i,0]*416)) + ',' + str(int(anchors[i,1]*416)) + ', '
            
    print(out_string[:-2])

def run_kmeans(ann_dims, anchor_num):
    ann_num = ann_dims.shape[0]
    iterations = 0
    prev_assignments = np.ones(ann_num)*(-1)
    iteration = 0
    old_distances = np.zeros((ann_num, anchor_num))

    indices = [random.randrange(ann_dims.shape[0]) for i in range(anchor_num)]
    centroids = ann_dims[indices]
    anchor_dim = ann_dims.shape[1]

    while True:
        distances = []
        iteration += 1
        for i in range(ann_num):
            d = 1 - IOU(ann_dims[i], centroids)
            distances.append(d)
        distances = np.array(distances) # distances.shape = (ann_num, anchor_num)

        print("iteration {}: dists = {}".format(iteration, np.sum(np.abs(old_distances-distances))))

        #assign samples to centroids
        assignments = np.argmin(distances,axis=1)

        if (assignments == prev_assignments).all() :
            return centroids

        #calculate new centroids
        centroid_sums=np.zeros((anchor_num, anchor_dim), np.float)
        for i in range(ann_num):
            centroid_sums[assignments[i]]+=ann_dims[i]
        for j in range(anchor_num):
            centroids[j] = centroid_sums[j]/(np.sum(assignments==j) + 1e-6)

        prev_assignments = assignments.copy()
        old_distances = distances.copy()

def _main_():
    config_path = "config.json"
    num_anchors = 9

    with open(config_path) as config_buffer:
        config = json.loads(config_buffer.read())

    train_imgs, train_labels = parse_voc_annotation(
        config['train']['train_annot_folder'],
        config['train']['train_image_folder'],
        config['train']['cache_name'],
        config['model']['labels']
    )

    # run k_mean to find the anchors
    annotation_dims = []
    for image in train_imgs:
        print(image['filename'])
        for obj in image['object']:
            relative_w = (float(obj['xmax']) - float(obj['xmin']))/image['width']
            relatice_h = (float(obj["ymax"]) - float(obj['ymin']))/image['height']
            annotation_dims.append(tuple(map(float, (relative_w,relatice_h))))

    annotation_dims = np.array(annotation_dims)
    centroids = run_kmeans(annotation_dims, num_anchors)

    # write anchors to file
    print('\naverage IOU for', num_anchors, 'anchors:', '%0.2f' % avg_IOU(annotation_dims, centroids))
    print_anchors(centroids)

# %%
_main_()
# Out:
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0000_00532_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0000_02187_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0000_05696_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0000_06886_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0000_08244_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0001_05318_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0002_02183_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0002_02554_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0003_02063_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0003_07398_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0004_06801_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0005_00490_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0005_00512_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0005_02171_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0006_05286_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0006_06035_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0006_06797_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0007_02188_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0007_05159_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0009_00490_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0009_02194_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0009_05325_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0010_00004_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0010_02063_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0011_00515_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0012_04539_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0013_05647_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0014_02176_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0017_00195_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0018_07248_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0019_01137_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0019_02163_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0019_06895_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0020_00536_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0020_02063_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0020_07156_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0021_06361_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0022_01753_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0023_05798_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0025_00457_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0027_06458_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0028_00196_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0028_07031_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0028_08102_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0031_07285_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0036_00507_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0038_01762_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0038_08198_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0039_01689_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0039_04131_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0039_05169_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0041_00436_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0041_00486_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0041_00507_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0041_00697_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0041_00951_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0041_04542_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0041_05679_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0042_01141_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0042_01875_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0042_05741_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0043_01133_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0043_01757_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0043_01879_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0044_04330_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0045_01558_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0045_01674_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0045_01821_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0046_00961_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0046_01762_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0046_06241_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0046_06635_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0047_00717_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0047_00970_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0047_01152_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0047_01868_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0047_03046_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0048_01264_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0048_01689_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0048_01752_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0048_02005_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0049_03047_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0049_04098_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0049_04676_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0050_01152_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0051_01757_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0053_01877_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0053_04375_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0054_00940_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0054_03047_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0054_04076_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0054_05482_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0054_05705_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0054_06642_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0055_01981_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0056_01153_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0056_01595_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0056_05671_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0057_01126_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0057_04356_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0057_05184_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0057_06324_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0058_01145_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0058_01153_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0058_02021_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0058_05613_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0059_04445_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0059_04971_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0059_06835_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0100_00168_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0100_00252_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0100_01126_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0100_01595_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0100_08183_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0101_00088_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0101_01261_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0101_01391_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0101_01715_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0101_05739_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0101_07107_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0102_00398_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0102_04296_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0102_06556_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0102_07105_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0102_07390_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0103_01261_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0103_01697_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0103_05539_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0103_06841_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0104_00171_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0104_08083_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0105_01594_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0106_00586_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0106_08292_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0107_00252_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0108_00929_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0108_00973_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0108_05849_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0109_01594_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0109_02232_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0110_00060_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0110_01653_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0110_01670_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0110_01967_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0110_04515_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0111_01678_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0111_05692_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0112_00522_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0112_01081_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0112_01913_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0112_05816_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0112_06759_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0113_00687_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0113_04405_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0113_08001_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0114_00145_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0114_00442_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0114_05537_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0114_05671_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0115_01636_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0115_01853_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0115_01928_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0115_01937_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0115_02514_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0115_06646_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0115_08259_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0116_00148_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0116_00818_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0116_00986_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0116_02019_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0116_04019_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0116_04147_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0117_00060_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0117_00091_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0117_00148_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0117_01160_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0117_05755_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0118_00092_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0118_00095_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0118_00750_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0118_00754_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0118_00818_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0118_00942_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0118_01640_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0118_01967_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0118_01998_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0118_04709_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0118_07169_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0118_08084_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0119_00145_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0119_01947_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0119_02023_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0119_02244_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0119_02246_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0119_02501_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0119_06336_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0120_00060_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0120_00061_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0120_00262_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0120_00591_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0120_02089_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0120_04228_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0120_06890_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0120_07193_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0120_08370_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0121_00375_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0121_00503_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0121_00820_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0121_00920_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0121_02555_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0121_04617_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0121_04848_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0121_06062_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0121_06228_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0121_06796_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0121_07251_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0122_00752_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0122_00983_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0122_01404_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0122_02548_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0122_05419_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0122_07108_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0123_00754_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0123_00918_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0123_01841_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0123_01939_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0123_02088_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0123_04299_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0123_05055_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0123_05664_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0123_06125_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0124_00307_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0124_00323_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0124_00779_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0124_00806_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0124_00942_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0124_01377_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0124_01853_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0124_02016_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0124_04420_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0124_04443_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0124_04666_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0124_06079_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0124_06343_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0125_00127_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0125_00375_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0125_00786_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0125_00984_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0125_01920_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0125_02237_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0125_04420_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0125_05869_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0125_06196_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0126_00061_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0126_00136_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0126_00940_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0126_04109_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0126_04483_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0126_05624_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0126_05966_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0126_06297_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0127_00055_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0127_01738_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0127_01915_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0127_01968_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0127_04803_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0127_08112_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0128_00503_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0128_00733_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0128_01676_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0128_02532_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0128_04019_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0128_05556_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0128_06831_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0128_08102_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0129_00633_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0129_00751_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0129_00806_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0129_00819_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0129_01074_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0129_06028_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0129_06048_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0129_06692_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0129_07029_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0130_00538_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0130_00760_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0130_00833_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0130_01078_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0130_05460_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0131_00223_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0131_00329_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0131_00436_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0131_00635_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0131_00660_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0131_00733_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0131_00774_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0131_00942_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0131_00954_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0131_02540_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0131_02584_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0131_04891_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0131_05287_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0131_05638_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0131_07186_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0132_00984_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0132_02227_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0132_04142_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0132_04633_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0132_04939_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0132_05835_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0132_06084_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0132_08092_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0133_01915_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0133_02013_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0133_02544_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0133_02608_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0133_04344_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0133_04876_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0133_05630_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0133_05979_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0134_00217_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0134_00408_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0134_00579_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0134_00660_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0134_01049_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0134_01670_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0134_02562_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0134_05469_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0134_05943_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0134_07394_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0135_00503_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0135_00957_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0135_01754_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0135_08228_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0136_00205_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0136_00507_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0136_00659_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0136_01022_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0136_01678_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0136_02503_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0136_02540_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0136_02545_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0136_05068_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0136_07165_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0137_00194_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0137_01124_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0137_01848_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0137_01947_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0137_02503_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0137_02601_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0137_05575_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0137_06221_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0137_06297_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0137_06846_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0137_08135_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0138_00196_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0138_00331_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0138_01676_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0138_04418_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0138_04577_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0138_04710_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0138_05001_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0138_05250_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0139_00214_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0139_01915_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0139_02551_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0139_04415_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0139_05725_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0139_06601_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0139_06709_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0139_07138_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0139_07305_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0139_07352_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0140_00057_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0140_00065_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0140_02257_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0140_02522_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0140_02549_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0140_02608_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0140_04869_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0140_06114_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0140_07349_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0141_00373_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0141_00718_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0141_02242_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0141_04084_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0141_04768_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0141_05568_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0141_05722_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0142_00253_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0142_00769_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0142_01632_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0142_01919_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0142_02093_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0142_02613_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0142_06535_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0143_01360_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0143_01861_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0143_02079_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0143_02510_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0143_02523_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0143_02624_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0143_04342_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0143_04794_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0143_05732_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0143_05783_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0143_05857_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0143_06806_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0143_07365_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0143_08168_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0143_08257_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0144_00053_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0144_01003_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0144_02007_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0144_02519_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0144_02600_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0144_02609_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0144_02616_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0144_04987_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0144_08012_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0145_00462_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0145_02546_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0145_04083_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0145_04181_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0145_04373_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0146_00588_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0146_01335_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0146_02557_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0146_04190_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0146_05460_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0146_06245_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0146_06747_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0147_00127_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0147_00208_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0147_00438_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0147_02217_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0147_02236_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0147_02536_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0147_02594_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0147_02600_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0147_04388_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0147_04452_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0147_05075_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0147_05135_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0147_06572_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0147_06954_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0147_06999_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0147_08012_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0148_00001_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0148_00310_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0148_02583_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0148_04580_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0148_08252_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0149_00951_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0149_04597_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0149_04664_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0149_04677_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0149_05370_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0149_05849_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0149_06285_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0149_06389_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0149_06587_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0149_08181_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0150_00416_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0150_00460_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0150_01054_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0150_01360_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0150_01377_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0150_01640_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0150_02256_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0150_04096_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0150_04187_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0150_04802_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0150_04829_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0150_05844_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0150_05851_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0150_06837_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0150_08257_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0151_00052_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0151_02013_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0151_02019_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0151_04111_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0151_07240_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0151_08171_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0151_08249_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0152_00001_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0152_00988_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0152_01985_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0152_06205_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0152_08092_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0153_00460_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0153_00906_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0153_02505_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0153_02530_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0153_02574_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0153_03025_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0153_04351_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0153_05328_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0153_06070_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0154_00518_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0154_00769_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0154_01990_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0154_02212_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0154_02257_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0154_02580_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0154_03021_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0154_05226_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0154_06496_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0154_07191_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0155_00047_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0155_00418_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0155_01305_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0155_01524_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0156_04102_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0157_00083_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0157_00096_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0157_00906_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0157_01727_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0157_01915_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0157_02500_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0157_02592_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0157_05295_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0158_00834_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0158_01702_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0158_05358_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0158_05596_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0158_06483_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0158_06500_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0158_06656_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0158_08078_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0159_00418_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0159_02276_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0159_02500_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0159_02577_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0159_03023_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0159_04714_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0159_04916_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0159_05256_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0200_04363_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0200_05891_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0200_06533_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0200_08054_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0200_08375_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0201_04010_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0201_05010_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0201_05131_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0201_05320_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0201_06401_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0202_03024_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0202_04129_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0202_04179_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0202_04264_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0202_04589_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0202_04805_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0202_05672_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0203_00419_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0203_00488_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0203_01062_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0203_02003_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0203_04832_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0203_05531_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0203_06622_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0203_09520_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0204_05256_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0204_07385_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0205_00866_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0205_04086_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0205_04478_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0205_05743_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0205_06486_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0205_07100_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0205_07244_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0205_08135_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0206_00158_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0206_04440_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0206_05783_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0206_07238_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0206_08036_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0207_00521_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0207_01409_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0207_04185_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0207_04299_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0207_04411_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0207_07240_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0208_01163_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0208_01987_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0208_04293_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0208_05067_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0208_06253_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0208_06505_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0208_06556_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0208_07011_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0209_02619_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0209_04147_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0209_04404_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0209_04563_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0209_04828_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0209_05225_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0209_05405_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0209_06283_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0209_06894_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0209_08007_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0209_08094_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0209_08290_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0210_01045_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0210_02219_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0210_04345_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0210_04453_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0210_04510_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0210_05414_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0210_06105_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0210_07395_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0211_00866_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0211_01098_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0211_01448_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0211_04855_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0211_05326_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0211_07006_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0211_08346_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0212_00158_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0212_00289_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0212_01946_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0212_02007_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0212_06671_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0212_07303_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0213_00318_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0213_01426_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0213_02212_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0213_02232_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0213_04627_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0214_04674_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0214_05762_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0214_06062_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0215_01946_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0215_04767_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0215_04770_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0215_05824_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0215_05885_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0215_06112_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0216_04264_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0216_04997_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0217_00819_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0217_04676_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0217_05820_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0218_00868_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0218_01944_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0218_06096_b.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/0219_01300_b.jpg
# ...
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815292616.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815292617.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815292618.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815292619.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815292620.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293007.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293008.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293015.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293016.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293017.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293018.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293019.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293020.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293021.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293022.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293227.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293228.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293235.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293236.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293237.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293238.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293239.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293240.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293241.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293242.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293243.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293244.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293245.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293246.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293498.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293499.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293507.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293508.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293509.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293510.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293511.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293512.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293513.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293514.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293515.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293516.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293517.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293908.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293909.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293910.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293911.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293912.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293913.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293914.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293915.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293916.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293917.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293918.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293919.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293920.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293921.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293922.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293923.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815293924.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294254.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294255.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294256.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294257.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294258.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294259.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294260.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294261.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294262.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294263.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294264.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294265.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294266.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294267.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294268.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294269.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294270.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294271.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294272.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294285.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294286.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294287.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294288.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294289.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294290.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294291.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294292.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294293.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294294.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294295.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294296.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294297.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294298.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294299.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294300.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294301.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294414.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294415.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294416.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294417.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294418.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294419.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294420.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294425.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294426.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294427.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294428.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294429.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294430.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294431.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294432.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294691.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294692.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294693.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294694.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294695.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294696.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294697.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294698.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294704.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294705.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294706.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294707.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294708.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294709.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294962.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294963.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294964.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294965.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294966.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294967.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294968.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294969.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294970.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294971.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294972.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815294973.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815295308.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815295309.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815295310.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815295311.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815295312.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815295313.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815295314.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815295315.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815295316.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815295317.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815295318.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815295381.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815295382.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815295383.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815295384.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815295385.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815295386.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate081529539.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815295390.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815295391.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815295392.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815295393.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815295394.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate081529540.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate081529541.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate081529542.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate081529543.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate081529544.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815295488.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815295493.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815295494.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815295495.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815295496.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815295497.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815295498.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815295499.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815295500.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815295501.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815295502.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815295503.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate0815295504.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate081529737.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate081529738.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate081529739.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate081529740.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate081529741.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate081529742.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate081529743.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate081529744.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate081529745.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate081529746.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate081529747.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate081529770.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate081529771.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate081529772.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate081529773.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate081529774.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate081529775.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate081529776.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate081529777.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate081529778.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate081529779.jpg
# /content/drive/My Drive/AI_COLAB/YOLO_plate/GreenParking/plate081529780.jpg
# iteration 1: dists = 11291.753387957731
# iteration 2: dists = 621.1940338401564
# iteration 3: dists = 298.05196521697616
# iteration 4: dists = 185.71231716178633
# iteration 5: dists = 111.71452662075805
# iteration 6: dists = 67.19036200495232
# iteration 7: dists = 41.81892622748654
# iteration 8: dists = 36.61513700762886
# iteration 9: dists = 37.07908938965202
# iteration 10: dists = 23.56257957835395
# iteration 11: dists = 38.340434056813365
# iteration 12: dists = 13.378329709417683
# iteration 13: dists = 9.775256669395901
# iteration 14: dists = 13.34129145337002
# iteration 15: dists = 13.310546611177127
#
# average IOU for 9 anchors: 0.91
# 13,18, 19,28, 56,74, 63,85, 66,91, 70,94, 72,99, 75,105, 79,112

# %%
import argparse
import os
import numpy as np
import json
from voc import parse_voc_annotation
from yolo import create_yolov3_model, dummy_loss
from generator import BatchGenerator
from utils.utils import normalize, evaluate, makedirs
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.optimizers import Adam
from callbacks import CustomModelCheckpoint, CustomTensorBoard
from utils.multi_gpu_model import multi_gpu_model
import tensorflow as tf
import keras
from keras.models import load_model
# Out:
# Using TensorFlow backend.

# %%
def create_training_instances(
    train_annot_folder,
    train_image_folder,
    train_cache,
    valid_annot_folder,
    valid_image_folder,
    valid_cache,
    labels,
):
    # parse annotations of the training set
    train_ints, train_labels = parse_voc_annotation(train_annot_folder, train_image_folder, train_cache, labels)

    # parse annotations of the validation set, if any, otherwise split the training set
    if os.path.exists(valid_annot_folder):
        valid_ints, valid_labels = parse_voc_annotation(valid_annot_folder, valid_image_folder, valid_cache, labels)
    else:
        print("valid_annot_folder not exists. Spliting the trainining set.")

        train_valid_split = int(0.8*len(train_ints))
        np.random.seed(0)
        np.random.shuffle(train_ints)
        np.random.seed()

        valid_ints = train_ints[train_valid_split:]
        train_ints = train_ints[:train_valid_split]

    # compare the seen labels with the given labels in config.json
    if len(labels) > 0:
        overlap_labels = set(labels).intersection(set(train_labels.keys()))

        print('Seen labels: \t'  + str(train_labels) + '\n')
        print('Given labels: \t' + str(labels))

        # return None, None, None if some given label is not in the dataset
        if len(overlap_labels) < len(labels):
            print('Some labels have no annotations! Please revise the list of labels in the config.json.')
            return None, None, None
    else:
        print('No labels are provided. Train on all seen labels.')
        print(train_labels)
        labels = train_labels.keys()

    max_box_per_image = max([len(inst['object']) for inst in (train_ints + valid_ints)])

    return train_ints, valid_ints, sorted(labels), max_box_per_image

def create_callbacks(saved_weights_name, tensorboard_logs, model_to_save):
    makedirs(tensorboard_logs)
    
    early_stop = EarlyStopping(
        monitor     = 'loss', 
        min_delta   = 0.01, 
        patience    = 5, 
        mode        = 'min', 
        verbose     = 1
    )
    checkpoint = CustomModelCheckpoint(
        model_to_save   = model_to_save,
        filepath        = saved_weights_name + '{epoch:02d}.h5', 
        monitor         = 'loss', 
        verbose         = 1, 
        save_best_only  = True, 
        mode            = 'min', 
        period          = 1
    )
    reduce_on_plateau = ReduceLROnPlateau(
        monitor  = 'loss',
        factor   = 0.1,
        patience = 2,
        verbose  = 1,
        mode     = 'min',
        epsilon  = 0.01,
        cooldown = 0,
        min_lr   = 0
    )
    tensorboard = CustomTensorBoard(
        log_dir                = tensorboard_logs,
        write_graph            = True,
        write_images           = True,
    )    
    return [early_stop, checkpoint, reduce_on_plateau, tensorboard]

def create_model(
    nb_class, 
    anchors, 
    max_box_per_image, 
    max_grid, batch_size, 
    warmup_batches, 
    ignore_thresh, 
    multi_gpu, 
    saved_weights_name, 
    lr,
    grid_scales,
    obj_scale,
    noobj_scale,
    xywh_scale,
    class_scale  
):
    if multi_gpu > 1:
        with tf.device('/cpu:0'):
            template_model, infer_model = create_yolov3_model(
                nb_class            = nb_class, 
                anchors             = anchors, 
                max_box_per_image   = max_box_per_image, 
                max_grid            = max_grid, 
                batch_size          = batch_size//multi_gpu, 
                warmup_batches      = warmup_batches,
                ignore_thresh       = ignore_thresh,
                grid_scales         = grid_scales,
                obj_scale           = obj_scale,
                noobj_scale         = noobj_scale,
                xywh_scale          = xywh_scale,
                class_scale         = class_scale
            )
    else:
        template_model, infer_model = create_yolov3_model(
            nb_class            = nb_class, 
            anchors             = anchors, 
            max_box_per_image   = max_box_per_image, 
            max_grid            = max_grid, 
            batch_size          = batch_size, 
            warmup_batches      = warmup_batches,
            ignore_thresh       = ignore_thresh,
            grid_scales         = grid_scales,
            obj_scale           = obj_scale,
            noobj_scale         = noobj_scale,
            xywh_scale          = xywh_scale,
            class_scale         = class_scale
        )  

    # load the pretrained weight if exists, otherwise load the backend weight only
    if os.path.exists(saved_weights_name): 
        print("\nLoading pretrained weights.\n")
        template_model.load_weights(saved_weights_name)
    else:
        template_model.load_weights("backend.h5", by_name=True)       

    if multi_gpu > 1:
        train_model = multi_gpu_model(template_model, gpus=multi_gpu)
    else:
        train_model = template_model      

    optimizer = Adam(lr=lr, clipnorm=0.001)
    train_model.compile(loss=dummy_loss, optimizer=optimizer)             

    return train_model, infer_model

def _main_():
    config_path = "config.json"

    with open(config_path) as config_buffer:    
        config = json.loads(config_buffer.read())

    ###############################
    #   Parse the annotations 
    ###############################
    train_ints, valid_ints, labels, max_box_per_image = create_training_instances(
        config['train']['train_annot_folder'],
        config['train']['train_image_folder'],
        config['train']['cache_name'],
        config['valid']['valid_annot_folder'],
        config['valid']['valid_image_folder'],
        config['valid']['cache_name'],
        config['model']['labels']
    )
    print('\nTraining on: \t' + str(labels) + '\n')

    ###############################
    #   Create the generators 
    ###############################    
    train_generator = BatchGenerator(
        instances           = train_ints, 
        anchors             = config['model']['anchors'],   
        labels              = labels,        
        downsample          = 32, # ratio between network input's size and network output's size, 32 for YOLOv3
        max_box_per_image   = max_box_per_image,
        batch_size          = config['train']['batch_size'],
        min_net_size        = config['model']['min_input_size'],
        max_net_size        = config['model']['max_input_size'],   
        shuffle             = True, 
        jitter              = 0.3, 
        norm                = normalize
    )
    
    valid_generator = BatchGenerator(
        instances           = valid_ints, 
        anchors             = config['model']['anchors'],   
        labels              = labels,        
        downsample          = 32, # ratio between network input's size and network output's size, 32 for YOLOv3
        max_box_per_image   = max_box_per_image,
        batch_size          = config['train']['batch_size'],
        min_net_size        = config['model']['min_input_size'],
        max_net_size        = config['model']['max_input_size'],   
        shuffle             = True, 
        jitter              = 0.0, 
        norm                = normalize
    )

    ###############################
    #   Create the model 
    ###############################
    if os.path.exists(config['train']['saved_weights_name']): 
        config['train']['warmup_epochs'] = 0
    warmup_batches = config['train']['warmup_epochs'] * (config['train']['train_times']*len(train_generator))   

    #os.environ['CUDA_VISIBLE_DEVICES'] = config['train']['gpus']
    #multi_gpu = len(config['train']['gpus'].split(','))
    multi_gpu = 1
    print("PASS")

    train_model, infer_model = create_model(
        nb_class            = len(labels), 
        anchors             = config['model']['anchors'], 
        max_box_per_image   = max_box_per_image, 
        max_grid            = [config['model']['max_input_size'], config['model']['max_input_size']], 
        batch_size          = config['train']['batch_size'], 
        warmup_batches      = warmup_batches,
        ignore_thresh       = config['train']['ignore_thresh'],
        multi_gpu           = multi_gpu,
        saved_weights_name  = config['train']['saved_weights_name'],
        lr                  = config['train']['learning_rate'],
        grid_scales         = config['train']['grid_scales'],
        obj_scale           = config['train']['obj_scale'],
        noobj_scale         = config['train']['noobj_scale'],
        xywh_scale          = config['train']['xywh_scale'],
        class_scale         = config['train']['class_scale'],
    )
    print("PASS2")

    ###############################
    #   Kick off the training
    ###############################
    callbacks = create_callbacks(config['train']['saved_weights_name'], config['train']['tensorboard_dir'], infer_model)
  
    print("PASS3")
    
    train_model.fit_generator(
        generator        = train_generator, 
        steps_per_epoch  = len(train_generator) * config['train']['train_times'], 
        epochs           = config['train']['nb_epochs'] + config['train']['warmup_epochs'], 
        verbose          = 2 if config['train']['debug'] else 1,
        callbacks        = callbacks, 
        workers          = 4,
        max_queue_size   = 8
    )
    
    print("PASS4")
    # make a GPU version of infer_model for evaluation
    if multi_gpu > 1:
        infer_model = load_model(config['train']['saved_weights_name'])

    ###############################
    #   Run the evaluation
    ###############################   
    # compute mAP for all the classes
    average_precisions = evaluate(infer_model, valid_generator)

    # print the score
    for label, average_precision in average_precisions.items():
        print(labels[label] + ': {:.4f}'.format(average_precision))
    print('mAP: {:.4f}'.format(sum(average_precisions.values()) / len(average_precisions)))

# %%
_main_()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0730 01:54:50.352249 139760906897280 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0730 01:54:50.372330 139760906897280 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0730 01:54:50.381887 139760906897280 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0730 01:54:50.409641 139760906897280 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0730 01:54:50.410706 139760906897280 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# valid_annot_folder not exists. Spliting the trainining set.
# Seen labels: 	{'plate': 2476}
#
# Given labels: 	['plate']
#
# Training on: 	['plate']
#
# PASS
# W0730 01:54:51.052079 139760906897280 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0730 01:54:57.613011 139760906897280 deprecation.py:323] From /content/drive/My Drive/AI_COLAB/YOLO_V3_PLATE/yolo.py:24: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0730 01:54:57.938201 139760906897280 deprecation.py:323] From /content/drive/My Drive/AI_COLAB/YOLO_V3_PLATE/yolo.py:179: Print (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2018-08-20.
# Instructions for updating:
# Use tf.print instead of tf.Print. Note that tf.print returns a no-output operator that directly prints the output. Outside of defuns or eager mode, this operator will not be executed unless it is directly specified in session.run or used as a control dependency for other operators. This is only a concern in graph mode. Below is an example of how to ensure tf.print executes in graph mode:
# ```python
#     sess = tf.compat.v1.Session()
#     with sess.as_default():
#         tensor = tf.range(10)
#         print_op = tf.print(tensor)
#         with tf.control_dependencies([print_op]):
#           out = tf.add(tensor, tensor)
#         sess.run(out)
#     ```
# Additionally, to use tf.print in python 2.7, users must make sure to import
# the following:
#
#   `from __future__ import print_function`
#
# W0730 01:54:58.075619 139760906897280 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2018: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# W0730 01:55:05.591788 139760906897280 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:1065: UserWarning: `epsilon` argument is deprecated and will be removed, use `min_delta` instead.
#   warnings.warn('`epsilon` argument is deprecated and '
# PASS2
# PASS3
# W0730 01:55:27.031853 139760906897280 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:850: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# W0730 01:55:27.033979 139760906897280 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:853: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
# Epoch 1/13
# resizing:  416 416
# resizing:  384 384
# resizing:  352 352
# resizing:  448 448
# resizing:  288 288
# resizing:  352 352
# resizing:  320 320
# resizing:  416 416
# resizing:  320 320
# resizing:  416 416
# resizing:  288 288
# resizing:  288 288
# resizing:  384 384
# resizing:  352 352
# resizing:  448 448
# resizing:  352 352
# resizing:  352 352
# resizing:  416 416
# resizing:  384 384
# resizing:  352 352
# resizing:  352 352
# resizing:  416 416
# resizing:  448 448
# resizing:  352 352
# resizing:  352 352
# resizing:  288 288
# resizing:  416 416
# resizing:  416 416
# resizing:  320 320
# resizing:  352 352
# resizing:  288 288
# resizing:  384 384
# resizing:  288 288
# resizing:  352 352
# resizing:  352 352
# resizing:  288 288
# resizing:  320 320
# resizing:  448 448
# resizing:  352 352
# resizing:  288 288
# resizing:  320 320
# resizing:  320 320
# resizing:  384 384
# resizing:  448 448
# resizing:  384 384
# resizing:  320 320
# resizing:  384 384
# resizing:  320 320
# resizing:  352 352
# resizing:  288 288
# resizing:  384 384
# resizing:  288 288
# resizing:  416 416
# resizing:  416 416
# resizing:  320 320
# resizing:  448 448
# resizing:  352 352
# resizing:  288 288
# resizing:  352 352
# resizing:  288 288
# resizing:  416 416
# resizing:  416 416
# resizing:  416 416
# resizing:  448 448
# resizing:  352 352
# resizing:  416 416
# resizing:  448 448
# resizing:  384 384
# resizing:  288 288
# resizing:  352 352
# resizing:  448 448
# resizing:  416 416
# resizing:  416 416
# resizing:  384 384
# resizing:  288 288
# resizing:  352 352
# resizing:  320 320
# resizing:  352 352
# resizing:  416 416
# resizing:  448 448
# resizing:  416 416
# resizing:  416 416
# resizing:  288 288
# resizing:  384 384
# resizing:  288 288
# resizing:  416 416
# resizing:  288 288
# resizing:  288 288
# resizing:  288 288
# resizing:  384 384
# resizing:  416 416
# resizing:  416 416
# resizing:  320 320
# resizing:  384 384
# resizing:  320 320
# resizing:  288 288
# resizing:  352 352
# resizing:  416 416
# resizing:  320 320
# resizing:  384 384
# resizing:  352 352
# resizing:  384 384
# resizing:  288 288
# resizing:  384 384
# resizing:  416 416
# resizing:  416 416
# resizing:  352 352
# resizing:  320 320
# resizing:  416 416
# resizing:  352 352
# resizing:  320 320
# resizing:  320 320
# resizing:  352 352
# resizing:  416 416
# resizing:  288 288
# resizing:  320 320
# resizing:  352 352
# resizing:  320 320
# resizing:  288 288
# resizing:  320 320
# resizing:  416 416
# resizing:  384 384
# resizing:  320 320
# resizing:  288 288
# resizing:  448 448
# resizing:  384 384
# resizing:  352 352
# resizing:  352 352
# resizing:  384 384
# resizing:  320 320
# resizing:  384 384
# resizing:  288 288
# resizing:  352 352
# resizing:  384 384
# resizing:  320 320
# resizing:  384 384
# resizing:  384 384
# resizing:  416 416
# resizing:  288 288
# resizing:  288 288
# resizing:  384 384
# resizing:  352 352
# resizing:  384 384
# resizing:  320 320
# resizing:  384 384
# resizing:  288 288
# resizing:  416 416
# resizing:  352 352
# resizing:  416 416
# resizing:  288 288
# resizing:  448 448
# resizing:  288 288
# resizing:  416 416
# resizing:  416 416
# resizing:  384 384
# resizing:  320 320
# resizing:  352 352
# resizing:  352 352
# resizing:  384 384
# resizing:  352 352
# resizing:  352 352
# resizing:  288 288
# resizing:  352 352
# resizing:  352 352
# resizing:  288 288
# resizing:  288 288
# resizing:  352 352
# resizing:  352 352
# resizing:  448 448
# resizing:  352 352
# resizing:  352 352
# resizing:  384 384
# resizing:  320 320
# resizing:  288 288
# resizing:  384 384
# resizing:  288 288
# resizing:  320 320
# resizing:  416 416
# resizing:  416 416
# resizing:  352 352
# resizing:  384 384
# resizing:  416 416
# resizing:  416 416
# resizing:  416 416
# resizing:  384 384
# resizing:  352 352
# resizing:  352 352
# resizing:  288 288
# resizing:  352 352
# resizing:  384 384
# resizing:  288 288
# resizing:  320 320
# resizing:  416 416
# resizing:  384 384
# resizing:  416 416
# resizing:  288 288
# resizing:  320 320
# resizing:  416 416
# resizing:  416 416
# resizing:  288 288
# resizing: resizing:  416 416
#  384 384
# resizing:  384 384
# resizing:  320 320
# resizing:  288 288
# resizing:  416 416
# resizing:  384 384
# resizing:  352 352
# resizing:  320 320
# resizing:  320 320
# resizing:  416 416
# resizing:  352 352
# resizing:  288 288
# resizing:  448 448
# resizing:  288 288
# resizing:  384 384
# resizing:  320 320
# resizing:  384 384
# resizing:  352 352
# resizing:  448 448
# resizing:  288 288
# resizing:  416 416
# resizing:  416 416
# resizing:  416 416
# resizing:  416 416
# resizing:  320 320
# resizing:  416 416
# resizing:  384 384
# resizing:  352 352
# resizing:  352 352
# resizing:  448 448
# resizing:  352 352
# resizing:  384 384
# resizing:  352 352
# resizing:  288 288
# resizing:  288 288
# resizing:  320 320
# resizing:  352 352
# resizing:  384 384
# resizing:  448 448
# resizing:  416 416
# resizing:  352 352
# resizing:  448 448
# resizing:  448 448
# resizing:  384 384
# resizing:  352 352
# resizing:  416 416
# resizing:  288 288
# resizing:  416 416
# resizing:  416 416
# resizing:  384 384
# resizing:  288 288
# resizing:  320 320
# resizing:  288 288
# resizing:  384 384
# resizing:  448 448
# resizing:  288 288
# resizing:  320 320
# resizing:  288 288
# resizing:  352 352
# resizing:  448 448
# resizing:  352 352
# resizing:  288 288
# resizing:  288 288
# resizing:  352 352
# resizing:  448 448
# resizing:  320 320
# resizing:  320 320
# resizing:  416 416
# resizing:  288 288
# resizing:  448 448
# resizing:  320 320
# resizing:  416 416
# resizing:  320 320
# resizing:  384 384
# resizing:  352 352
# resizing:  384 384
# resizing:  288 288
# resizing:  416 416
# resizing:  448 448
# resizing:  288 288
# resizing:  352 352
# resizing:  384 384
# resizing:  448 448
# resizing:  352 352
# resizing:  448 448
# resizing:  320 320
# resizing:  416 416
# resizing:  352 352
# resizing:  288 288
# resizing:  448 448
# resizing:  352 352
# resizing:  416 416
# resizing:  448 448
# resizing:  352 352
# resizing:  288 288
# resizing:  384 384
# resizing:  448 448
# resizing:  416 416
# resizing:  384 384
# resizing:  416 416
# resizing:  448 448
# resizing:  320 320
# resizing:  320 320
# resizing:  384 384
# resizing:  384 384
# resizing:  384 384
# resizing:  352 352
# resizing:  416 416
# resizing:  320 320
# resizing:  384 384
# resizing:  416 416
# resizing:  288 288
# resizing:  320 320
# resizing:  288 288
# resizing:  320 320
# resizing:  320 320
# resizing:  352 352
# resizing:  384 384
# resizing:  288 288
# resizing:  416 416
# resizing:  416 416
# resizing:  320 320
# resizing:  448 448
# resizing:  416 416
# resizing:  384 384
# resizing:  352 352
# resizing:  384 384
# resizing:  352 352
# resizing:  320 320
# resizing:  352 352
# resizing:  288 288
# resizing:  416 416
# resizing:  416 416
# resizing:  416 416
# resizing:  448 448
# resizing:  448 448
# resizing:  384 384
# resizing:  288 288
# resizing:  448 448
# resizing:  288 288
# resizing:  448 448
# resizing:  416 416
# resizing:  288 288
# resizing:  384 384
# resizing:  352 352
# resizing:  384 384
# resizing:  288 288
# resizing:  416 416
# resizing:  384 384
# resizing:  384 384
# resizing:  288 288
# resizing:  448 448
# resizing:  352 352
# resizing:  384 384
# resizing:  416 416
# resizing:  320 320
# resizing:  384 384
# resizing:  416 416
# resizing:  448 448
# resizing:  288 288
# resizing:  416 416
# resizing:  320 320
# resizing:  448 448
# resizing:  320 320
# resizing:  416 416
# resizing:  448 448
# resizing:  288 288
# resizing:  288 288
# resizing:  448 448
# resizing:  352 352
# resizing:  416 416
# resizing:  384 384
# resizing:  416 416
# resizing:  320 320
# resizing:  384 384
# resizing:  288 288
# resizing:  288 288
# resizing:  384 384
# resizing:  384 384
# resizing:  384 384
# resizing:  288 288
# resizing:  288 288
# resizing:  384 384
# resizing:  320 320
# resizing:  288 288
# resizing:  416 416
# resizing:  320 320
# resizing:  448 448
# resizing:  448 448
# resizing:  416 416
# resizing:  320 320
# resizing:  288 288
# resizing:  320 320
# resizing:  448 448
# resizing:  384 384
# resizing:  384 384
# resizing:  288 288
# resizing:  352 352
# resizing:  416 416
#  - 2915s - loss: 37.6600 - yolo_layer_1_loss: 4.6901 - yolo_layer_2_loss: 8.2848 - yolo_layer_3_loss: 24.6851
#
# Epoch 00001: loss improved from inf to 37.65999, saving model to plate_weight.h5
# Epoch 2/13
# resizing:  320 320
# resizing:  448 448
# resizing:  416 416
# resizing:  352 352
# resizing:  416 416
# resizing:  416 416
# resizing:  416 416
# resizing:  384 384
# resizing:  384 384
# resizing:  384 384
# resizing:  416 416
# resizing:  320 320
# resizing:  352 352
# resizing:  448 448
# resizing:  288 288
# resizing:  352 352
# resizing:  288 288
# resizing:  448 448
# resizing:  352 352
# resizing:  320 320
# resizing:  448 448
# resizing:  288 288
# resizing:  352 352
# resizing:  384 384
# resizing:  384 384
# resizing:  288 288
# resizing:  352 352
# resizing:  448 448
# resizing:  448 448
# resizing:  288 288
# resizing:  416 416
# resizing:  448 448
# resizing:  352 352
# resizing:  320 320
# resizing:  320 320
# resizing:  448 448
# resizing:  320 320
# resizing:  288 288
# resizing:  384 384
# resizing:  320 320
# resizing:  352 352
# resizing:  352 352
# resizing:  416 416
# resizing:  320 320
# resizing:  352 352
# resizing:  352 352
# resizing:  448 448
# resizing:  448 448
# resizing:  320 320
# resizing:  288 288
# resizing:  352 352
# resizing:  288 288
# resizing:  288 288
# resizing:  416 416
# resizing:  288 288
# resizing:  288 288
# resizing:  416 416
# resizing:  320 320
# resizing:  352 352
# resizing:  384 384
# resizing:  416 416
# resizing:  416 416
# resizing:  288 288
# resizing:  384 384
# resizing:  352 352
# resizing:  288 288
# resizing:  288 288
# resizing:  320 320
# resizing:  288 288
# resizing:  288 288
# resizing:  320 320
# resizing:  416 416
# resizing:  448 448
# resizing:  288 288
# resizing:  352 352
# resizing:  288 288
# resizing:  448 448
# resizing:  448 448
# resizing:  384 384
# resizing:  448 448
# resizing:  320 320
# resizing:  416 416
# resizing:  352 352
# resizing:  352 352
# resizing:  448 448
# resizing:  288 288
# resizing:  320 320
# resizing:  320 320
# resizing:  448 448
# resizing:  288 288
# resizing:  384 384
# resizing:  288 288
# resizing:  320 320
# resizing:  416 416
# resizing:  320 320
# resizing:  448 448
# resizing:  320 320
# resizing:  416 416
# resizing:  352 352
# resizing:  352 352
# resizing:  384 384
# resizing:  384 384
# resizing:  352 352
# resizing:  352 352
# resizing:  384 384
# resizing:  448 448
# resizing:  448 448
# resizing:  384 384
# resizing:  352 352
# resizing:  352 352
# resizing:  320 320
# resizing:  288 288
# resizing:  352 352
# resizing:  448 448
# resizing:  288 288
# resizing:  320 320
# resizing:  384 384
# resizing:  320 320
# resizing:  448 448
# resizing:  448 448
# resizing:  320 320
# resizing:  416 416
# resizing:  352 352
# resizing:  384 384
# resizing:  416 416
# resizing:  288 288
# resizing:  416 416
# resizing:  416 416
# resizing:  448 448
# resizing:  352 352
# resizing:  448 448
# resizing:  288 288
# resizing:  320 320
# resizing:  448 448
# resizing:  384 384
# resizing:  416 416
# resizing:  352 352
# resizing:  288 288
# resizing:  288 288
# resizing:  384 384
# resizing:  416 416
# resizing:  416 416
# resizing:  320 320
# resizing:  352 352
# resizing:  288 288
# resizing:  320 320
# resizing:  352 352
# resizing:  320 320
# resizing:  320 320
# resizing:  384 384
# resizing:  352 352
# resizing:  320 320
# resizing:  448 448
# resizing:  384 384
# resizing:  288 288
# resizing:  416 416
# resizing:  416 416
# resizing:  352 352
# resizing:  288 288
# resizing:  384 384
# resizing:  448 448
# resizing:  416 416
# resizing:  352 352
# resizing:  448 448
# resizing:  352 352
# resizing:  352 352
# resizing:  384 384
# resizing:  448 448
# resizing:  448 448
# resizing:  384 384
# resizing:  352 352
# resizing:  352 352
# resizing:  320 320
# resizing:  352 352
# resizing:  352 352
# resizing:  288 288
# resizing:  416 416
# resizing:  320 320
# resizing:  352 352
# resizing:  288 288
# resizing:  352 352
# resizing:  320 320
# resizing:  320 320
# resizing:  288 288
# resizing:  448 448
# resizing:  288 288
# resizing:  352 352
# resizing:  448 448
# resizing:  320 320
# resizing:  416 416
# resizing:  448 448
# resizing:  352 352
# resizing:  320 320
# resizing:  288 288
# resizing:  288 288
# resizing:  416 416
# resizing:  448 448
# resizing:  384 384
# resizing:  416 416
# resizing:  320 320
# resizing:  288 288
# resizing:  448 448
# resizing:  352 352
# resizing:  448 448
# resizing:  384 384
# resizing:  416 416
# resizing:  384 384
# resizing:  416 416
# resizing:  416 416
# resizing:  352 352
# resizing:  384 384
# resizing:  448 448
# resizing:  352 352
# resizing:  288 288
# resizing:  288 288
# resizing:  288 288
# resizing:  448 448
# resizing:  384 384
# resizing:  320 320
# resizing:  448 448
# resizing:  448 448
# resizing:  448 448
# resizing:  448 448
# resizing:  352 352
# resizing:  320 320
# resizing:  320 320
# resizing:  320 320
# resizing:  384 384
# resizing:  416 416
# resizing:  448 448
# resizing:  416 416
# resizing:  416 416
# resizing:  288 288
# resizing:  416 416
# resizing:  320 320
# resizing:  384 384
# resizing:  416 416
# resizing:  416 416
# resizing:  352 352
# resizing:  352 352
# resizing:  352 352
# resizing:  416 416
# resizing:  288 288
# resizing:  384 384
# resizing:  320 320
# resizing:  320 320
# resizing:  448 448
# resizing:  448 448
# resizing:  448 448
# resizing:  416 416
# resizing:  448 448
# resizing:  416 416
# resizing:  448 448
# resizing:  384 384
# resizing:  352 352
# resizing:  288 288
# resizing:  288 288
# resizing:  448 448
# resizing:  448 448
# resizing:  352 352
# resizing:  352 352
# resizing:  448 448
# resizing:  416 416
# resizing:  448 448
# resizing:  416 416
# resizing:  416 416
# resizing:  416 416
# resizing:  352 352
# resizing:  352 352
# resizing:  288 288
# resizing:  352 352
# resizing:  320 320
# resizing:  352 352
# resizing:  320 320
# resizing:  416 416
# resizing:  416 416
# resizing:  288 288
# resizing:  448 448
# resizing:  352 352
# resizing:  320 320
# resizing:  288 288
# resizing:  288 288
# resizing:  288 288
# resizing:  320 320
# resizing:  320 320
# resizing:  384 384
# resizing:  448 448
# resizing:  448 448
# resizing:  352 352
# resizing:  352 352
# resizing:  384 384
# resizing:  320 320
# resizing:  416 416
# resizing:  288 288
# resizing:  288 288
# resizing:  352 352
# resizing:  416 416
# resizing:  320 320
# resizing:  320 320
# resizing:  320 320
# resizing:  416 416
# resizing:  384 384
# resizing:  448 448
# resizing:  320 320
# resizing:  448 448
# resizing:  384 384
# resizing:  288 288
# resizing:  352 352
# resizing:  352 352
# resizing:  384 384
# resizing:  416 416
# resizing:  352 352
# resizing:  448 448
# resizing:  288 288
# resizing:  288 288
# resizing:  384 384
# resizing:  384 384
# resizing:  352 352
# resizing:  416 416
# resizing:  416 416
# resizing:  352 352
# resizing:  288 288
# resizing:  384 384
# resizing:  384 384
# resizing:  384 384
# resizing:  320 320
# resizing:  352 352
# resizing:  320 320
# resizing:  448 448
# resizing:  416 416
# resizing:  352 352
# resizing:  416 416
# resizing:  448 448
# resizing:  384 384
# resizing:  320 320
# resizing:  448 448
# resizing:  320 320
# resizing:  448 448
# resizing:  416 416
# resizing:  288 288
# resizing:  448 448
# resizing:  416 416
# resizing:  320 320
# resizing:  288 288
# resizing:  448 448
# resizing:  320 320
# resizing:  320 320
# resizing:  448 448
# resizing:  416 416
# resizing:  416 416
# resizing:  288 288
# resizing:  416 416
# resizing:  288 288
# resizing:  288 288
# resizing:  288 288
# resizing:  448 448
# resizing:  384 384
# resizing:  416 416
# resizing:  288 288
# resizing:  288 288
# resizing:  352 352
# resizing:  384 384
# resizing:  352 352
# resizing:  416 416
# resizing:  448 448
# resizing:  448 448
# resizing:  384 384
# resizing:  320 320
# resizing:  320 320
# resizing:  352 352
# resizing:  384 384
# resizing:  384 384
# resizing:  416 416
# resizing:  448 448
# resizing:  320 320
# resizing:  320 320
# resizing:  352 352
# resizing:  448 448
# resizing:  288 288
# resizing:  416 416
# resizing:  352 352
# resizing:  448 448
# resizing:  352 352
# resizing:  448 448
# resizing:  352 352
# resizing:  352 352
# resizing:  384 384
# resizing:  416 416
# resizing:  384 384
# resizing:  352 352
# resizing:  448 448
# resizing:  416 416
# resizing:  352 352
# resizing:  288 288
# resizing:  448 448
# resizing:  352 352
# resizing:  288 288
# resizing:  352 352
# resizing:  320 320
# resizing:  416 416
# resizing:  352 352
# resizing:  352 352
#  - 2861s - loss: 13.2774 - yolo_layer_1_loss: 1.7673 - yolo_layer_2_loss: 3.8558 - yolo_layer_3_loss: 7.6544
#
# Epoch 00002: loss improved from 37.65999 to 13.27743, saving model to plate_weight.h5
# resizing:  352 352
# Epoch 3/13
# resizing:  288 288
# resizing:  320 320
# resizing:  448 448
# resizing:  352 352
# resizing:  384 384
# resizing:  352 352
# resizing:  352 352
# resizing:  288 288
# resizing:  288 288
# resizing:  448 448
# resizing:  352 352
# resizing:  288 288
# resizing:  416 416
# resizing:  384 384
# resizing:  352 352
# resizing:  416 416
# resizing:  448 448
# resizing:  448 448
# resizing:  448 448
# resizing:  352 352
# resizing:  320 320
# resizing:  320 320
# resizing:  448 448
# resizing:  320 320
# resizing:  288 288
# resizing:  352 352
# resizing:  288 288
# resizing:  320 320
# resizing:  352 352
# resizing:  416 416
# resizing:  416 416
# resizing:  320 320
# resizing:  448 448
# resizing:  384 384
# resizing:  352 352
# resizing:  384 384
# resizing:  352 352
# resizing:  352 352
# resizing:  352 352
# resizing:  384 384
# resizing:  352 352
# resizing:  288 288
# resizing:  416 416
# resizing:  448 448
# resizing:  320 320
# resizing:  448 448
# resizing:  448 448
# resizing:  448 448
# resizing:  288 288
# resizing:  320 320
# resizing:  416 416
# resizing:  416 416
# resizing:  416 416
# resizing:  320 320
# resizing:  416 416
# resizing:  288 288
# resizing:  352 352
# resizing:  288 288
# resizing:  384 384
# resizing:  320 320
# resizing:  352 352
# resizing:  448 448
# resizing:  288 288
# resizing:  352 352
# resizing:  384 384
# resizing:  288 288
# resizing:  320 320
# resizing:  352 352
# resizing:  320 320
# resizing:  384 384
# resizing:  352 352
# resizing:  416 416
# resizing:  384 384
# resizing:  384 384
# resizing:  320 320
# resizing:  416 416
# resizing:  448 448
# resizing:  448 448
# resizing:  416 416
# resizing:  384 384
# resizing:  288 288
# resizing:  352 352
# resizing:  416 416
# resizing:  384 384
# resizing:  352 352
# resizing:  416 416
# resizing:  448 448
# resizing:  320 320
# resizing:  416 416
# resizing:  320 320
# resizing:  352 352
# resizing:  320 320
# resizing:  352 352
# resizing:  352 352
# resizing:  288 288
# resizing:  416 416
# resizing:  384 384
# resizing:  448 448
# resizing:  384 384
# resizing:  352 352
# resizing:  448 448
# resizing:  288 288
# resizing:  384 384
# resizing:  320 320
# resizing:  448 448
# resizing:  448 448
# resizing:  320 320
# resizing:  448 448
# resizing:  320 320
# resizing:  384 384
# resizing:  288 288
# resizing:  448 448
# resizing:  288 288
# resizing:  448 448
# resizing:  352 352
# resizing:  288 288
# resizing:  416 416
# resizing:  384 384
# resizing:  320 320
# resizing:  352 352
# resizing:  352 352
# resizing:  416 416
# resizing:  352 352
# resizing:  320 320
# resizing:  384 384
# resizing:  320 320
# resizing:  384 384
# resizing:  320 320
# resizing:  320 320
# resizing:  352 352
# resizing:  416 416
# resizing:  352 352
# resizing:  448 448
# resizing:  448 448
# resizing:  448 448
# resizing:  288 288
# resizing:  352 352
# resizing:  416 416
# resizing:  384 384
# resizing:  416 416
# resizing:  448 448
# resizing:  288 288
# resizing:  352 352
# resizing:  384 384
# resizing:  320 320
# resizing:  448 448
# resizing:  448 448
# resizing:  384 384
# resizing:  320 320
# resizing:  416 416
# resizing:  416 416
# resizing:  384 384
# resizing:  288 288
# resizing:  448 448
# resizing:  320 320
# resizing:  288 288
# resizing:  448 448
# resizing:  448 448
# resizing:  448 448
# resizing:  448 448
# resizing:  416 416
# resizing:  288 288
# resizing:  288 288
# resizing:  448 448
# resizing:  384 384
# resizing:  288 288
# resizing:  352 352
# resizing:  384 384
# resizing:  352 352
# resizing:  384 384
# resizing:  320 320
# resizing:  320 320
# resizing:  384 384
# resizing:  320 320
# resizing:  288 288
# resizing:  448 448
# resizing:  320 320
# resizing:  384 384
# resizing:  288 288
# resizing:  416 416
# resizing:  320 320
# resizing:  288 288
# resizing:  320 320
# resizing:  320 320
# resizing:  448 448
# resizing:  448 448
# resizing:  288 288
# resizing:  320 320
# resizing:  288 288
# resizing:  352 352
# resizing:  416 416
# resizing:  288 288
# resizing:  288 288
# resizing:  352 352
# resizing:  288 288
# resizing:  448 448
# resizing:  384 384
# resizing:  320 320
# resizing:  384 384
# resizing:  352 352
# resizing:  416 416
# resizing:  320 320
# resizing:  416 416
# resizing:  448 448
# resizing:  288 288
# resizing:  384 384
# resizing:  448 448
# resizing:  320 320
# resizing:  384 384
# resizing:  288 288
# resizing:  384 384
# resizing:  288 288
# resizing:  448 448
# resizing:  384 384
# resizing:  320 320
# resizing:  320 320
# resizing:  416 416
# resizing:  384 384
# resizing:  416 416
# resizing:  288 288
# resizing:  352 352
# resizing:  448 448
# resizing:  320 320
# resizing:  352 352
# resizing:  320 320
# resizing:  384 384
# resizing:  384 384
# resizing:  352 352
# resizing:  384 384
# resizing:  448 448
# resizing:  320 320
# resizing:  416 416
# resizing:  288 288
# resizing:  352 352
# resizing:  320 320
# resizing:  320 320
# resizing:  384 384
# resizing:  416 416
# resizing:  448 448
# resizing:  320 320
# resizing:  352 352
# resizing:  288 288
# resizing:  352 352
# resizing:  384 384
# resizing:  288 288
# resizing:  352 352
# resizing:  384 384
# resizing:  416 416
# resizing:  384 384
# resizing:  320 320
# resizing:  288 288
# resizing:  320 320
# resizing:  352 352
# resizing:  416 416
# resizing:  288 288
# resizing:  352 352
# resizing:  416 416
# resizing:  352 352
# resizing:  352 352
# resizing:  320 320
# resizing:  352 352
# resizing:  288 288
# resizing:  416 416
# resizing:  352 352
# resizing:  416 416
# resizing:  448 448
# resizing:  448 448
# resizing:  416 416
# resizing:  320 320
# resizing:  384 384
# resizing:  416 416
# resizing:  288 288
# resizing:  384 384
# resizing:  352 352
# resizing:  416 416
# resizing:  352 352
# resizing:  448 448
# resizing:  384 384
# resizing:  352 352
# resizing:  384 384
# resizing:  384 384
# resizing:  352 352
# resizing:  288 288
# resizing:  384 384
# resizing:  352 352
# resizing:  320 320
# resizing:  448 448
# resizing:  352 352
# resizing:  320 320
# resizing:  448 448
# resizing:  448 448
# resizing:  448 448
# resizing:  416 416
# resizing:  448 448
# resizing:  352 352
# resizing:  416 416
# resizing:  448 448
# resizing:  288 288
# resizing:  384 384
# resizing:  352 352
# resizing:  416 416
# resizing:  448 448
# resizing:  416 416
# resizing:  352 352
# resizing:  320 320
# resizing:  384 384
# resizing:  448 448
# resizing:  384 384
# resizing:  320 320
# resizing:  384 384
# resizing:  448 448
# resizing:  320 320
# resizing:  416 416
# resizing:  384 384
# resizing:  288 288
# resizing:  384 384
# resizing:  384 384
# resizing:  448 448
# resizing:  352 352
# resizing:  288 288
# resizing:  448 448
# resizing:  448 448
# resizing:  288 288
# resizing:  384 384
# resizing:  320 320
# resizing:  448 448
# resizing:  448 448
# resizing:  384 384
# resizing:  448 448
# resizing:  352 352
# resizing:  320 320
# resizing:  384 384
# resizing:  416 416
# resizing:  416 416
# resizing:  448 448
# resizing:  416 416
# resizing:  320 320
# resizing:  384 384
# resizing:  384 384
# resizing:  352 352
# resizing:  320 320
# resizing:  320 320
# resizing:  416 416
# resizing:  320 320
# resizing:  448 448
# resizing:  352 352
# resizing:  320 320
# resizing:  448 448
# resizing:  352 352
# resizing:  384 384
# resizing:  416 416
# resizing:  448 448
# resizing:  384 384
# resizing:  320 320
# resizing:  288 288
# resizing:  320 320
# resizing:  448 448
# resizing:  384 384
# resizing:  352 352
# resizing:  448 448
# resizing:  416 416
# resizing:  416 416
# resizing:  384 384
# resizing:  288 288
# resizing:  416 416
# resizing:  384 384
# resizing:  288 288
# resizing:  448 448
# resizing:  384 384
# resizing:  416 416
# resizing:  320 320
# resizing:  288 288
# resizing:  288 288
# resizing:  384 384
# resizing:  448 448
# resizing:  288 288
# resizing:  320 320
# resizing:  288 288
# resizing:  384 384
# resizing:  288 288
# resizing:  416 416
# resizing:  448 448
# resizing:  384 384
# resizing:  320 320
# resizing:  448 448
# resizing:  320 320
# resizing:  448 448
# resizing:  384 384
# resizing:  320 320
# resizing:  352 352
# resizing:  288 288
# resizing:  384 384
# resizing:  448 448
# resizing:  416 416
# resizing:  288 288
# resizing:  288 288
# resizing:  384 384
#  - 2866s - loss: 9.3265 - yolo_layer_1_loss: 1.4189 - yolo_layer_2_loss: 3.4495 - yolo_layer_3_loss: 4.4582
#
# Epoch 00003: loss improved from 13.27743 to 9.32652, saving model to plate_weight.h5
# Epoch 4/13
# resizing:  352 352
# resizing:  320 320
# resizing:  288 288
# resizing:  416 416
# resizing:  320 320
# resizing:  416 416
# resizing:  384 384
# resizing:  416 416
